# %% [markdown]
# ### Logging

# %%
import logging
import re
import csv
import time
from pathlib import Path
from gensim.parsing.preprocessing import * #provides a number of convenience preprocessing functions optimized for speed
from gensim.models.word2vec import Word2Vec
import gensim
from multiprocessing import cpu_count
import pandas as pd
import os
from langua import Predict
languagePredictor = Predict()
import time

from itertools import islice
#logging.getLogger('').handlers = []  #To delete previous logging configuration
from dataDictionariesLexicons import dataDict, LexiconsEnsembl


logging.basicConfig(
    format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO,
    #If log into standard output and to a file is desired:
    #handlers=[logging.FileHandler("{0}/{1}.log".format('./', uniName)), #path, File name
    #         logging.StreamHandler()]
)

from outletsBiasRatings import outletsBiasRatingsAllSides, outletAbbreviationToFullName 

outletsBiasRatings = outletsBiasRatingsAllSides
outlets = list(outletsBiasRatings.keys())
print(len(outlets),outlets)
# Out:
# 47 ['alternet', 'democracynow', 'db', 'hp', 'theintercept', 'jacobin', 'motherjones', 'thenewyorker', 'thenation', 'slate', 'vox', 'cnn', 'nyt', 'abcnews', 'theatlantic', 'buzzfeed', 'cbs', 'economist', 'guardian', 'nbcnews', 'politico', 'timemagazine', 'wp', 'npr', 'ap', 'bbc', 'bloomberg', 'csm', 'reuters', 'thehill', 'usatoday', 'wsj', 'reason', 'we', 'wt', 'fox', 'americanspectator', 'bre', 'theblaze', 'cbn', 'dailycaller', 'dailymail', 'dailywire', 'thefederalist', 'nationalreview', 'nyp', 'newsmax']

# %%
# Pick 6 outlets to analyze (2 left, 2 center, 2 right) considering time range of articles
# and Allsides ratings
outlets = ['cbs','reuters','nyt', 'slate', 'csm', 'thehill', 'wt', 'nyp', 'dailymail']

# %% [markdown]
# ## Computing years intervals

# %%
startYear=2000
endYear = 2019
years = list(range(startYear,endYear+1))
intervalLength = 5

intervalsList = []
interval = []

for year in range(startYear,endYear+1):
    if year%intervalLength==0:
        intervalsList.append(interval)
        interval = []
    interval.append(year)
    
intervalsList.append(interval)
    
intervalsList.pop(0)

for interval in intervalsList:
    intervalName = str(interval[0])+'-'+str(interval[-1])
    print(intervalName)
intervalsList
# Out:
# 2000-2004
# 2005-2009
# 2010-2014
# 2015-2019
# [[2000, 2001, 2002, 2003, 2004],
#  [2005, 2006, 2007, 2008, 2009],
#  [2010, 2011, 2012, 2013, 2014],
#  [2015, 2016, 2017, 2018, 2019]]

# %%
workers = cpu_count()-2 #Number of workers to use for parallel processing. If None all available cores will be used.
print('Number of workers:', workers)
# Out:
# Number of workers: 14

# %%
current_dir = Path(os.getcwd())
base_dir = current_dir.parent
input_dir = base_dir / "scrambledArticlesForWord2vec"
model_dir = base_dir / "models"

# %%
import logging

def load_and_preprocess_sentences(file_path):
    try:
        with file_path.open('r', encoding='utf-8') as file:
            return [line.strip().split(' ') for line in file.readlines()]
    except Exception as e:
        logging.error(f"Failed to read from {file_path}: {e}")
        return []


def train_model(sentences, previous_model_path):
    if not sentences:
        print("No sentences provided for training.")
        return None  # Return None if no sentences to train on

    tic = time.time()
    if previous_model_path and os.path.exists(previous_model_path):
        try:
            print(f"Loading model from {previous_model_path}")
            model = Word2Vec.load(previous_model_path)
            model.build_vocab(sentences, update=True)  # Update the vocabulary
        except Exception as e:
            print(f"Error loading the model from {previous_model_path}: {e}")
            print("Training new model instead")
            model = Word2Vec(sentences, vector_size=300, window=10, min_count=5, workers=4)
            model.build_vocab(sentences)  # Building vocabulary for the new model
    else:
        print("Training new model")
        model = Word2Vec(vector_size=300, window=10, min_count=5, workers=workers, hs=0, negative = 10, sample = 0.0001, epochs=5)
        model.build_vocab(sentences)  # Building vocabulary for the new model

    model.train(sentences, total_examples=len(sentences), epochs=model.epochs)

    toc = time.time()
    computation_time = toc - tic
    print(f"Computing time for training the model: {computation_time} seconds")
    words_in_corpus = sum(len(sentence) for sentence in sentences)
    print(f"Number of words processed per second: {words_in_corpus / computation_time}")
    print(f"Most frequent words in model: {model.wv.index_to_key[:10]}")

    return model

# %%
for outlet in outlets:
    logging.info(outlet)
    previous_model_path = None  # Initialize the previous model path

    for interval in intervalsList:
        output_file_name = f"{interval[0]}-{interval[-1]}"
        print(f"Processing interval {output_file_name}")
        input_file_path = input_dir / outlet / f"{output_file_name}.csv"
        output_path = model_dir / outlet
        output_path.mkdir(parents=True, exist_ok=True)
        
        sentences = load_and_preprocess_sentences(input_file_path)
        if not sentences:
            print(f"No sentences found in {input_file_path}, skipping interval {output_file_name}")
            continue

        model = train_model(sentences, previous_model_path)
        if model:
            output_file_path = output_path / f"{output_file_name}.model"
            model.save(str(output_file_path))
            print(f"Model saved to {output_file_path}")
            previous_model_path = str(output_file_path)  # Update the previous model path for the next interval
        else:
            print(f"\033[1;31mSkipping training for interval {output_file_name} due to insufficient data\033[0m")
            previous_model_path = None  # Reset if training was not successful

        # Evaluation
        try:
            logging.info(" Similarity evaluation: %s", model.wv.evaluate_word_pairs('wordsim353.tsv', restrict_vocab=50000))
        except Exception as e:
            logging.error("Exception during word similarity evaluation: %s", e)
        # Analogies
        try:
            model.wv.evaluate_word_analogies('questions-words.txt', restrict_vocab=30000)
        except Exception as e:
            logging.error("Exception during word analogy evaluation: %s", e)

        logging.info("----------------------------------------------------")            
    logging.info("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
# Out:
# 2024-05-01 03:10:43,867 : INFO : cbs
# Processing interval 2000-2004
# 2024-05-01 03:10:44,716 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=0, vector_size=300, alpha=0.025>', 'datetime': '2024-05-01T03:10:44.716234', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'created'}
# 2024-05-01 03:10:44,716 : INFO : collecting all words and their counts
# 2024-05-01 03:10:44,716 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2024-05-01 03:10:44,909 : INFO : PROGRESS: at sentence #10000, processed 2792625 words, keeping 75162 word types
# Training new model
# 2024-05-01 03:10:45,133 : INFO : PROGRESS: at sentence #20000, processed 5919188 words, keeping 117194 word types
# 2024-05-01 03:10:45,413 : INFO : PROGRESS: at sentence #30000, processed 9138063 words, keeping 151612 word types
# 2024-05-01 03:10:45,670 : INFO : PROGRESS: at sentence #40000, processed 12630907 words, keeping 181733 word types
# 2024-05-01 03:10:45,919 : INFO : PROGRESS: at sentence #50000, processed 16271370 words, keeping 208892 word types
# 2024-05-01 03:10:46,243 : INFO : PROGRESS: at sentence #60000, processed 19919024 words, keeping 235961 word types
# 2024-05-01 03:10:46,273 : INFO : collected 238302 word types from a corpus of 20224891 raw words and 60869 sentences
# 2024-05-01 03:10:46,274 : INFO : Creating a fresh vocabulary
# 2024-05-01 03:10:46,365 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=5 retains 69924 unique words (29.34% of original 238302, drops 168378)', 'datetime': '2024-05-01T03:10:46.364998', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2024-05-01 03:10:46,365 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=5 leaves 19986808 word corpus (98.82% of original 20224891, drops 238083)', 'datetime': '2024-05-01T03:10:46.365369', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2024-05-01 03:10:46,463 : INFO : deleting the raw counts dictionary of 238302 items
# 2024-05-01 03:10:46,465 : INFO : sample=0.0001 downsamples 645 most-common words
# 2024-05-01 03:10:46,465 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 15878116.006795915 word corpus (79.4%% of prior 19986808)', 'datetime': '2024-05-01T03:10:46.465665', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2024-05-01 03:10:46,625 : INFO : estimated required memory for 69924 words and 300 dimensions: 202779600 bytes
# 2024-05-01 03:10:46,625 : INFO : resetting layer weights
# 2024-05-01 03:10:46,679 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2024-05-01T03:10:46.679980', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'build_vocab'}
# 2024-05-01 03:10:46,680 : INFO : Word2Vec lifecycle event {'msg': 'training model with 14 workers on 69924 vocabulary and 300 features, using sg=0 hs=0 sample=0.0001 negative=10 window=10 shrink_windows=True', 'datetime': '2024-05-01T03:10:46.680321', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'train'}
# 2024-05-01 03:10:47,686 : INFO : EPOCH 0 - PROGRESS: at 23.56% examples, 3210209 words/s, in_qsize 28, out_qsize 0
# 2024-05-01 03:10:48,686 : INFO : EPOCH 0 - PROGRESS: at 45.13% examples, 3218492 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:10:49,688 : INFO : EPOCH 0 - PROGRESS: at 63.47% examples, 3170726 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:10:50,688 : INFO : EPOCH 0 - PROGRESS: at 81.75% examples, 3171752 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:10:51,676 : INFO : EPOCH 0: training on 20224891 raw words (15878723 effective words) took 5.0s, 3179361 effective words/s
# 2024-05-01 03:10:52,679 : INFO : EPOCH 1 - PROGRESS: at 23.82% examples, 3256490 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:10:53,680 : INFO : EPOCH 1 - PROGRESS: at 45.85% examples, 3281353 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:10:54,681 : INFO : EPOCH 1 - PROGRESS: at 64.91% examples, 3253068 words/s, in_qsize 28, out_qsize 0
# 2024-05-01 03:10:55,684 : INFO : EPOCH 1 - PROGRESS: at 83.29% examples, 3241485 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:10:56,588 : INFO : EPOCH 1: training on 20224891 raw words (15879199 effective words) took 4.9s, 3234027 effective words/s
# 2024-05-01 03:10:57,592 : INFO : EPOCH 2 - PROGRESS: at 22.74% examples, 3102726 words/s, in_qsize 28, out_qsize 1
# 2024-05-01 03:10:58,596 : INFO : EPOCH 2 - PROGRESS: at 44.02% examples, 3135635 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:10:59,597 : INFO : EPOCH 2 - PROGRESS: at 63.18% examples, 3154150 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:11:00,597 : INFO : EPOCH 2 - PROGRESS: at 81.46% examples, 3159527 words/s, in_qsize 26, out_qsize 1
# 2024-05-01 03:11:01,600 : INFO : EPOCH 2 - PROGRESS: at 99.87% examples, 3165006 words/s, in_qsize 3, out_qsize 1
# 2024-05-01 03:11:01,606 : INFO : EPOCH 2: training on 20224891 raw words (15878565 effective words) took 5.0s, 3166022 effective words/s
# 2024-05-01 03:11:02,608 : INFO : EPOCH 3 - PROGRESS: at 22.68% examples, 3098046 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:11:03,610 : INFO : EPOCH 3 - PROGRESS: at 45.08% examples, 3217761 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:11:04,614 : INFO : EPOCH 3 - PROGRESS: at 65.17% examples, 3264821 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:11:05,617 : INFO : EPOCH 3 - PROGRESS: at 84.34% examples, 3281914 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:11:06,423 : INFO : EPOCH 3: training on 20224891 raw words (15876789 effective words) took 4.8s, 3297551 effective words/s
# 2024-05-01 03:11:07,428 : INFO : EPOCH 4 - PROGRESS: at 23.98% examples, 3272887 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:11:08,431 : INFO : EPOCH 4 - PROGRESS: at 46.40% examples, 3319240 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:11:09,434 : INFO : EPOCH 4 - PROGRESS: at 66.44% examples, 3332173 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:11:10,437 : INFO : EPOCH 4 - PROGRESS: at 84.93% examples, 3304597 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:11:11,210 : INFO : EPOCH 4: training on 20224891 raw words (15877612 effective words) took 4.8s, 3318147 effective words/s
# 2024-05-01 03:11:11,210 : INFO : Word2Vec lifecycle event {'msg': 'training on 101124455 raw words (79390888 effective words) took 24.5s, 3236462 effective words/s', 'datetime': '2024-05-01T03:11:11.210689', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'train'}
# 2024-05-01 03:11:11,219 : INFO : Word2Vec lifecycle event {'fname_or_handle': '/Users/eddyji/GitRepos/01_TAD/models/cbs/2000-2004.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2024-05-01T03:11:11.219335', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'saving'}
# 2024-05-01 03:11:11,219 : INFO : storing np array 'vectors' to /Users/eddyji/GitRepos/01_TAD/models/cbs/2000-2004.model.wv.vectors.npy
# 2024-05-01 03:11:11,230 : INFO : storing np array 'syn1neg' to /Users/eddyji/GitRepos/01_TAD/models/cbs/2000-2004.model.syn1neg.npy
# 2024-05-01 03:11:11,244 : INFO : not storing attribute cum_table
# 2024-05-01 03:11:11,260 : INFO : saved /Users/eddyji/GitRepos/01_TAD/models/cbs/2000-2004.model
# 2024-05-01 03:11:11,270 : INFO : Skipping line #37 with OOV words: king	rook	5.92
# 2024-05-01 03:11:11,270 : INFO : Skipping line #42 with OOV words: fuck	sex	9.44
# 2024-05-01 03:11:11,271 : INFO : Skipping line #128 with OOV words: psychology	cognition	7.48
# 2024-05-01 03:11:11,272 : INFO : Skipping line #138 with OOV words: precedent	cognition	2.81
# 2024-05-01 03:11:11,272 : INFO : Skipping line #142 with OOV words: precedent	antecedent	6.04
# 2024-05-01 03:11:11,273 : INFO : Skipping line #169 with OOV words: water	seepage	6.56
# 2024-05-01 03:11:11,274 : INFO : Skipping line #210 with OOV words: hundred	percent	7.38
# 2024-05-01 03:11:11,274 : INFO : Skipping line #244 with OOV words: impartiality	interest	5.16
# 2024-05-01 03:11:11,275 : INFO : Skipping line #259 with OOV words: calculation	computation	8.44
# 2024-05-01 03:11:11,275 : INFO : Skipping line #276 with OOV words: five	month	3.38
# 2024-05-01 03:11:11,277 : INFO : Pearson correlation coefficient against wordsim353.tsv: 0.5467
# 2024-05-01 03:11:11,278 : INFO : Spearman rank-order correlation coefficient against wordsim353.tsv: 0.5773
# 2024-05-01 03:11:11,278 : INFO : Pairs with unknown words ratio: 2.8%
# 2024-05-01 03:11:11,279 : INFO :  Similarity evaluation: (PearsonRResult(statistic=0.5467442174278974, pvalue=3.9530815771495666e-28), SignificanceResult(statistic=0.5773346896704961, pvalue=7.075519876056685e-32), 2.8328611898017)
# 2024-05-01 03:11:11,284 : INFO : Evaluating word analogies for top 30000 words in the model on questions-words.txt
# Computing time for training the model: 26.49495577812195 seconds
# Number of words processed per second: 763348.7358639255
# Most frequent words in model: ['said', 'he', 'his', 'she', 'people', 'new', 'says', 'her', 'year', 'time']
# Model saved to /Users/eddyji/GitRepos/01_TAD/models/cbs/2000-2004.model
# 2024-05-01 03:11:11,875 : INFO : capital-common-countries: 50.4% (233/462)
# 2024-05-01 03:11:13,134 : INFO : capital-world: 41.7% (500/1200)
# 2024-05-01 03:11:13,421 : INFO : currency: 12.5% (5/40)
# 2024-05-01 03:11:15,515 : INFO : city-in-state: 17.6% (399/2266)
# 2024-05-01 03:11:15,900 : INFO : family: 43.1% (181/420)
# 2024-05-01 03:11:16,510 : INFO : gram1-adjective-to-adverb: 3.4% (28/812)
# 2024-05-01 03:11:16,806 : INFO : gram2-opposite: 2.6% (10/380)
# 2024-05-01 03:11:17,984 : INFO : gram3-comparative: 24.0% (320/1332)
# 2024-05-01 03:11:18,771 : INFO : gram4-superlative: 8.0% (79/992)
# 2024-05-01 03:11:19,362 : INFO : gram5-present-participle: 32.9% (231/702)
# 2024-05-01 03:11:20,350 : INFO : gram6-nationality-adjective: 58.0% (713/1229)
# 2024-05-01 03:11:21,506 : INFO : gram7-past-tense: 22.4% (350/1560)
# 2024-05-01 03:11:22,439 : INFO : gram8-plural: 36.5% (409/1122)
# 2024-05-01 03:11:22,808 : INFO : gram9-plural-verbs: 17.4% (73/420)
# 2024-05-01 03:11:22,809 : INFO : Quadruplets with out-of-vocabulary words: 33.8%
# 2024-05-01 03:11:22,810 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2024-05-01 03:11:22,811 : INFO : Total accuracy: 27.3% (3531/12937)
# 2024-05-01 03:11:22,815 : INFO : ----------------------------------------------------
# Processing interval 2005-2009
# 2024-05-01 03:11:24,611 : INFO : loading Word2Vec object from /Users/eddyji/GitRepos/01_TAD/models/cbs/2000-2004.model
# 2024-05-01 03:11:24,618 : INFO : loading wv recursively from /Users/eddyji/GitRepos/01_TAD/models/cbs/2000-2004.model.wv.* with mmap=None
# 2024-05-01 03:11:24,618 : INFO : loading vectors from /Users/eddyji/GitRepos/01_TAD/models/cbs/2000-2004.model.wv.vectors.npy with mmap=None
# 2024-05-01 03:11:24,628 : INFO : loading syn1neg from /Users/eddyji/GitRepos/01_TAD/models/cbs/2000-2004.model.syn1neg.npy with mmap=None
# 2024-05-01 03:11:24,642 : INFO : setting ignored attribute cum_table to None
# 2024-05-01 03:11:24,807 : INFO : Word2Vec lifecycle event {'fname': '/Users/eddyji/GitRepos/01_TAD/models/cbs/2000-2004.model', 'datetime': '2024-05-01T03:11:24.807582', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'loaded'}
# 2024-05-01 03:11:24,807 : INFO : collecting all words and their counts
# 2024-05-01 03:11:24,808 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# Loading model from /Users/eddyji/GitRepos/01_TAD/models/cbs/2000-2004.model
# 2024-05-01 03:11:25,033 : INFO : PROGRESS: at sentence #10000, processed 3295231 words, keeping 84298 word types
# 2024-05-01 03:11:25,237 : INFO : PROGRESS: at sentence #20000, processed 6401074 words, keeping 119269 word types
# 2024-05-01 03:11:25,427 : INFO : PROGRESS: at sentence #30000, processed 9317936 words, keeping 148554 word types
# 2024-05-01 03:11:25,617 : INFO : PROGRESS: at sentence #40000, processed 12121341 words, keeping 175631 word types
# 2024-05-01 03:11:25,791 : INFO : PROGRESS: at sentence #50000, processed 14769631 words, keeping 202504 word types
# 2024-05-01 03:11:25,958 : INFO : PROGRESS: at sentence #60000, processed 17293821 words, keeping 227186 word types
# 2024-05-01 03:11:26,143 : INFO : PROGRESS: at sentence #70000, processed 19963177 words, keeping 250545 word types
# 2024-05-01 03:11:26,302 : INFO : PROGRESS: at sentence #80000, processed 22383269 words, keeping 272492 word types
# 2024-05-01 03:11:26,451 : INFO : PROGRESS: at sentence #90000, processed 24592863 words, keeping 293317 word types
# 2024-05-01 03:11:26,600 : INFO : PROGRESS: at sentence #100000, processed 26815847 words, keeping 313938 word types
# 2024-05-01 03:11:26,757 : INFO : PROGRESS: at sentence #110000, processed 29139089 words, keeping 335414 word types
# 2024-05-01 03:11:26,919 : INFO : PROGRESS: at sentence #120000, processed 31448797 words, keeping 355269 word types
# 2024-05-01 03:11:27,076 : INFO : PROGRESS: at sentence #130000, processed 33842728 words, keeping 374379 word types
# 2024-05-01 03:11:27,236 : INFO : PROGRESS: at sentence #140000, processed 36247123 words, keeping 393386 word types
# 2024-05-01 03:11:27,406 : INFO : PROGRESS: at sentence #150000, processed 38821914 words, keeping 414121 word types
# 2024-05-01 03:11:27,505 : INFO : collected 425531 word types from a corpus of 40299780 raw words and 155509 sentences
# 2024-05-01 03:11:27,505 : INFO : Updating model with new vocabulary
# 2024-05-01 03:11:27,713 : INFO : Word2Vec lifecycle event {'msg': 'added 37993 new unique words (8.93% of original 425531) and increased the count of 57939 pre-existing words (13.62% of original 425531)', 'datetime': '2024-05-01T03:11:27.713829', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2024-05-01 03:11:27,859 : INFO : deleting the raw counts dictionary of 425531 items
# 2024-05-01 03:11:27,864 : INFO : sample=0.0001 downsamples 660 most-common words
# 2024-05-01 03:11:27,864 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 32136342.772980466 word corpus (80.6%% of prior 39867126)', 'datetime': '2024-05-01T03:11:27.864358', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2024-05-01 03:11:28,098 : INFO : estimated required memory for 95932 words and 300 dimensions: 278202800 bytes
# 2024-05-01 03:11:28,098 : INFO : updating layer weights
# 2024-05-01 03:11:28,204 : INFO : Word2Vec lifecycle event {'update': True, 'trim_rule': 'None', 'datetime': '2024-05-01T03:11:28.204113', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'build_vocab'}
# 2024-05-01 03:11:28,204 : WARNING : Effective 'alpha' higher than previous training cycles
# 2024-05-01 03:11:28,204 : INFO : Word2Vec lifecycle event {'msg': 'training model with 14 workers on 107917 vocabulary and 300 features, using sg=0 hs=0 sample=0.0001 negative=10 window=10 shrink_windows=True', 'datetime': '2024-05-01T03:11:28.204691', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'train'}
# 2024-05-01 03:11:29,207 : INFO : EPOCH 0 - PROGRESS: at 7.72% examples, 3142529 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:11
words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:12:01,187 : INFO : EPOCH 3 - PROGRESS: at 25.03% examples, 3151759 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:12:02,191 : INFO : EPOCH 3 - PROGRESS: at 34.80% examples, 3161314 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:12:03,194 : INFO : EPOCH 3 - PROGRESS: at 44.78% examples, 3171281 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:12:04,195 : INFO : EPOCH 3 - PROGRESS: at 55.87% examples, 3172752 words/s, in_qsize 28, out_qsize 0
# 2024-05-01 03:12:05,196 : INFO : EPOCH 3 - PROGRESS: at 67.33% examples, 3174250 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:12:06,196 : INFO : EPOCH 3 - PROGRESS: at 78.48% examples, 3176936 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:12:07,198 : INFO : EPOCH 3 - PROGRESS: at 88.87% examples, 3166665 words/s, in_qsize 28, out_qsize 0
# 2024-05-01 03:12:08,199 : INFO : EPOCH 3 - PROGRESS: at 98.77% examples, 3168793 words/s, in_qsize 28, out_qsize 0
# 2024-05-01 03:12:08,327 : INFO : EPOCH 3: training on 40299780 raw words (32152854 effective words) took 10.1s, 3170214 effective words/s
# 2024-05-01 03:12:09,331 : INFO : EPOCH 4 - PROGRESS: at 7.77% examples, 3154189 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:12:10,332 : INFO : EPOCH 4 - PROGRESS: at 16.30% examples, 3199749 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:12:11,332 : INFO : EPOCH 4 - PROGRESS: at 25.62% examples, 3215638 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:12:12,334 : INFO : EPOCH 4 - PROGRESS: at 35.67% examples, 3226848 words/s, in_qsize 26, out_qsize 1
# 2024-05-01 03:12:13,337 : INFO : EPOCH 4 - PROGRESS: at 45.68% examples, 3229452 words/s, in_qsize 28, out_qsize 0
# 2024-05-01 03:12:14,339 : INFO : EPOCH 4 - PROGRESS: at 57.09% examples, 3229014 words/s, in_qsize 28, out_qsize 0
# 2024-05-01 03:12:15,340 : INFO : EPOCH 4 - PROGRESS: at 68.60% examples, 3226034 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:12:16,340 : INFO : EPOCH 4 - PROGRESS: at 79.83% examples, 3226949 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:12:17,346 : INFO : EPOCH 4 - PROGRESS: at 90.71% examples, 3228148 words/s, in_qsize 28, out_qsize 0
# 2024-05-01 03:12:18,285 : INFO : EPOCH 4: training on 40299780 raw words (32150659 effective words) took 10.0s, 3228911 effective words/s
# 2024-05-01 03:12:18,286 : INFO : Word2Vec lifecycle event {'msg': 'training on 201498900 raw words (160764442 effective words) took 50.1s, 3210065 effective words/s', 'datetime': '2024-05-01T03:12:18.286296', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'train'}
# 2024-05-01 03:12:18,326 : INFO : Word2Vec lifecycle event {'fname_or_handle': '/Users/eddyji/GitRepos/01_TAD/models/cbs/2005-2009.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2024-05-01T03:12:18.326619', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'saving'}
# 2024-05-01 03:12:18,327 : INFO : storing np array 'vectors' to /Users/eddyji/GitRepos/01_TAD/models/cbs/2005-2009.model.wv.vectors.npy
# 2024-05-01 03:12:18,342 : INFO : storing np array 'syn1neg' to /Users/eddyji/GitRepos/01_TAD/models/cbs/2005-2009.model.syn1neg.npy
# 2024-05-01 03:12:18,361 : INFO : not storing attribute cum_table
# 2024-05-01 03:12:18,382 : INFO : saved /Users/eddyji/GitRepos/01_TAD/models/cbs/2005-2009.model
# 2024-05-01 03:12:18,392 : INFO : Skipping line #37 with OOV words: king	rook	5.92
# 2024-05-01 03:12:18,393 : INFO : Skipping line #42 with OOV words: fuck	sex	9.44
# 2024-05-01 03:12:18,394 : INFO : Skipping line #128 with OOV words: psychology	cognition	7.48
# 2024-05-01 03:12:18,394 : INFO : Skipping line #138 with OOV words: precedent	cognition	2.81
# 2024-05-01 03:12:18,395 : INFO : Skipping line #142 with OOV words: precedent	antecedent	6.04
# 2024-05-01 03:12:18,395 : INFO : Skipping line #169 with OOV words: water	seepage	6.56
# 2024-05-01 03:12:18,396 : INFO : Skipping line #210 with OOV words: hundred	percent	7.38
# 2024-05-01 03:12:18,397 : INFO : Skipping line #244 with OOV words: impartiality	interest	5.16
# 2024-05-01 03:12:18,397 : INFO : Skipping line #259 with OOV words: calculation	computation	8.44
# 2024-05-01 03:12:18,398 : INFO : Skipping line #276 with OOV words: five	month	3.38
# 2024-05-01 03:12:18,400 : INFO : Pearson correlation coefficient against wordsim353.tsv: 0.5783
# 2024-05-01 03:12:18,400 : INFO : Spearman rank-order correlation coefficient against wordsim353.tsv: 0.6033
# 2024-05-01 03:12:18,400 : INFO : Pairs with unknown words ratio: 2.8%
# 2024-05-01 03:12:18,401 : INFO :  Similarity evaluation: (PearsonRResult(statistic=0.5783234623495473, pvalue=5.272342280453082e-32), SignificanceResult(statistic=0.6033253225314124, pvalue=2.1967363494960472e-35), 2.8328611898017)
# 2024-05-01 03:12:18,404 : INFO : Evaluating word analogies for top 30000 words in the model on questions-words.txt
# Computing time for training the model: 53.675474882125854 seconds
# Number of words processed per second: 750804.3494445167
# Most frequent words in model: ['said', 'he', 'his', 'she', 'people', 'new', 'says', 'her', 'year', 'time']
# Model saved to /Users/eddyji/GitRepos/01_TAD/models/cbs/2005-2009.model
# 2024-05-01 03:12:18,885 : INFO : capital-common-countries: 61.9% (286/462)
# 2024-05-01 03:12:20,245 : INFO : capital-world: 52.5% (630/1200)
# 2024-05-01 03:12:20,328 : INFO : currency: 20.0% (8/40)
# 2024-05-01 03:12:22,087 : INFO : city-in-state: 58.9% (1334/2266)
# 2024-05-01 03:12:22,370 : INFO : family: 53.6% (225/420)
# 2024-05-01 03:12:22,935 : INFO : gram1-adjective-to-adverb: 8.4% (68/812)
# 2024-05-01 03:12:23,236 : INFO : gram2-opposite: 9.5% (36/380)
# 2024-05-01 03:12:24,300 : INFO : gram3-comparative: 39.8% (530/1332)
# 2024-05-01 03:12:25,009 : INFO : gram4-superlative: 14.3% (142/992)
# 2024-05-01 03:12:25,535 : INFO : gram5-present-participle: 44.9% (315/702)
# 2024-05-01 03:12:26,270 : INFO : gram6-nationality-adjective: 72.2% (887/1229)
# 2024-05-01 03:12:27,304 : INFO : gram7-past-tense: 40.3% (628/1560)
# 2024-05-01 03:12:28,105 : INFO : gram8-plural: 57.0% (639/1122)
# 2024-05-01 03:12:28,419 : INFO : gram9-plural-verbs: 31.2% (131/420)
# 2024-05-01 03:12:28,420 : INFO : Quadruplets with out-of-vocabulary words: 33.8%
# 2024-05-01 03:12:28,420 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2024-05-01 03:12:28,421 : INFO : Total accuracy: 45.3% (5859/12937)
# 2024-05-01 03:12:28,424 : INFO : ----------------------------------------------------
# Processing interval 2010-2014
# 2024-05-01 03:12:44,321 : INFO : loading Word2Vec object from /Users/eddyji/GitRepos/01_TAD/models/cbs/2005-2009.model
# 2024-05-01 03:12:44,336 : INFO : loading wv recursively from /Users/eddyji/GitRepos/01_TAD/models/cbs/2005-2009.model.wv.* with mmap=None
# 2024-05-01 03:12:48,229 : INFO : collected 502960 word types from a corpus of 51280192 raw words and 203569 sentences
# 2024-05-01 03:12:48,230 : INFO : Updating model with new vocabulary
# 2024-05-01 03:12:48,469 : INFO : Word2Vec lifecycle event {'msg': 'added 32388 new unique words (6.44% of original 502960) and increased the count of 76365 pre-existing words (15.18% of original 502960)', 'datetime': '2024-05-01T03:12:48.469052', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2024-05-01 03:12:48,632 : INFO : deleting the raw counts dictionary of 502960 items
# 2024-05-01 03:12:48,637 : INFO : sample=0.0001 downsamples 648 most-common words
# 2024-05-01 03:12:48,637 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 41070120.27180586 word corpus (80.9%% of prior 50767380)', 'datetime': '2024-05-01T03:12:48.637501', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2024-05-01 03:12:48,945 : INFO : estimated required memory for 108753 words and 300 dimensions: 315383700 bytes
# 2024-05-01 03:12:48,946 : INFO : updating layer weights
# 2024-05-01 03:12:49,109 : INFO : Word2Vec lifecycle event {'update': True, 'trim_rule': 'None', 'datetime': '2024-05-01T03:12:49.109850', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'build_vocab'}
# 2024-05-01 03:12:49,110 : WARNING : Effective 'alpha' higher than previous training cycles
# 2024-05-01 03:12:49,110 : INFO : Word2Vec lifecycle event {'msg': 'training model with 14 workers on 140305 vocabulary and 300 features, using sg=0 hs=0 sample=0.0001 negative=10 window=10 shrink_windows=True', 'datetime': '2024-05-01T03:12:49.110448', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'train'}
# 2024-05-01 03:12:50,115 : INFO : EPOCH 0 - PROGRESS: at 7.27% examples, 3060931 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:12:51,119 : INFO : EPOCH 0 - PROGRESS: at 15.04% examples, 3119218 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:12:52,123 : INFO : EPOCH 0 - PROGRESS: at 22.90% examples, 3134984 words/s, in_qsize 26, out_qsize 1
# 2024-05-01 03:12:53,124 : INFO : EPOCH 0 - PROGRESS: at 30.55% examples, 3119056 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:12:54,124 : INFO : EPOCH 0 - PROGRESS: at 38.39% examples, 3111377 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:12:55,128 : INFO : EPOCH 0 - PROGRESS: at 46.09% examples, 3116267 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:12:56,130 : INFO : EPOCH 0 - PROGRESS: at 53.83% examples, 3127821 words/s, in_qsize 26, out_qsize 1
# 2024-05-01 03:12:57,137 : INFO : EPOCH 0 - PROGRESS: at 61.62% examples, 3133908 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:12:58,138 : INFO : EPOCH 0 - PROGRESS: at 68.92% examples, 3127803 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:12:59,138 : INFO : EPOCH 0 - PROGRESS: at 76.62% examples, 3133775 words/s, in_qsize 28, out_qsize 0
# 2024-05-01 03:13:00,141 : INFO : EPOCH 0 - PROGRESS: at 84.45% examples, 3138057 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:13:01,141 : INFO : EPOCH 0 - PROGRESS: at 92.19% examples, 3137208 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:13:02,145 : INFO : EPOCH 0 - PROGRESS: at 99.58% examples, 3140322 words/s, in_qsize 22, out_qsize 1
# 2024-05-01 03:13:02,197 : INFO : EPOCH 0: training on 51280192 raw words (41098278 effective words) took 13.1s, 3141181 effective words/s
# 2024-05-01 03:13:03,203 : INFO : EPOCH 1 - PROGRESS: at 7.27% examples, 3060462 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:13:04,204 : INFO : EPOCH 1 - PROGRESS: at 14.99% examples, 3112513 words/s, in_qsize 28, out_qsize 1
# 2024-05-01 03:13:05,204 : INFO : EPOCH 1 - PROGRESS: at 22.84% examples, 3134546 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:13:06,207 : INFO : EPOCH 1 - PROGRESS: at 30.77% examples, 3142614 words/s, in_qsize 26, out_qsize 1
# 2024-05-01 03
words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:13:40,051 : INFO : EPOCH 3 - PROGRESS: at 92.84% examples, 3160586 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:13:41,024 : INFO : EPOCH 3: training on 51280192 raw words (41099290 effective words) took 13.0s, 3162202 effective words/s
# 2024-05-01 03:13:42,030 : INFO : EPOCH 4 - PROGRESS: at 7.17% examples, 3017944 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:13:43,034 : INFO : EPOCH 4 - PROGRESS: at 14.79% examples, 3066312 words/s, in_qsize 27, out_qsize 1
# 2024-05-01 03:13:44,037 : INFO : EPOCH 4 - PROGRESS: at 22.18% examples, 3035666 words/s, in_qsize 28, out_qsize 2
# 2024-05-01 03:13:45,039 : INFO : EPOCH 4 - PROGRESS: at 29.57% examples, 3017795 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:13:46,041 : INFO : EPOCH 4 - PROGRESS: at 37.22% examples, 3016766 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:13:47,042 : INFO : EPOCH 4 - PROGRESS: at 44.89% examples, 3031771 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:13:48,045 : INFO : EPOCH 4 - PROGRESS: at 52.45% examples, 3046604 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:13:49,046 : INFO : EPOCH 4 - PROGRESS: at 60.10% examples, 3057238 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:13:50,047 : INFO : EPOCH 4 - PROGRESS: at 67.56% examples, 3067800 words/s, in_qsize 26, out_qsize 1
# 2024-05-01 03:13:51,051 : INFO : EPOCH 4 - PROGRESS: at 75.21% examples, 3074349 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:13:52,051 : INFO : EPOCH 4 - PROGRESS: at 82.86% examples, 3081661 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:13:53,054 : INFO : EPOCH 4 - PROGRESS: at 90.34% examples, 3070618 words/s, in_qsize 26, out_qsize 1
# 2024-05-01 03:13:54,056 : INFO : EPOCH 4 - PROGRESS: at 97.44% examples, 3069901 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 03:13:54,402 : INFO : EPOCH 4: training on 51280192 raw words (41094901 effective words) took 13.4s, 3072714 effective words/s
# 2024-05-01 03:13:54,402 : INFO : Word2Vec lifecycle event {'msg': 'training on 256400960 raw words (205484840 effective words) took 65.3s, 3147169 effective words/s', 'datetime': '2024-05-01T03:13:54.402716', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'train'}
# 2024-05-01 03:13:54,510 : INFO : Word2Vec lifecycle event {'fname_or_handle': '/Users/eddyji/GitRepos/01_TAD/models/cbs/2010-2014.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2024-05-01T03:13:54.510504', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'saving'}
# 2024-05-01 03:13:54,511 : INFO : storing np array 'vectors' to /Users/eddyji/GitRepos/01_TAD/models/cbs/2010-2014.model.wv.vectors.npy
# 2024-05-01 03:13:54,532 : INFO : storing np array 'syn1neg' to /Users/eddyji/GitRepos/01_TAD/models/cbs/2010-2014.model.syn1neg.npy
# 2024-05-01 03:13:54,562 : INFO : not storing attribute cum_table
# 2024-05-01 03:13:54,581 : INFO : saved /Users/eddyji/GitRepos/01_TAD/models/cbs/2010-2014.model
# 2024-05-01 03:13:54,595 : INFO : Skipping line #37 with OOV words: king	rook	5.92
# 2024-05-01 03:13:54,596 : INFO : Skipping line #42 with OOV words: fuck	sex	9.44
# 2024-05-01 03:13:54,597 : INFO : Skipping line #128 with OOV words: psychology	cognition	7.48
# 2024-05-01 03:13:54,597 : INFO : Skipping line #138 with OOV words: precedent	cognition	2.81
# 2024-05-01 03:13:54,597 : INFO : Skipping line #142 with OOV words: precedent	antecedent	6.04
# 2024-05-01 03:13:54,598 : INFO : Skipping line #169 with OOV words: water	seepage	6.56
# 2024-05-01 03:13:54,599 : INFO : Skipping line #210 with OOV words: hundred	percent	7.38
# 2024-05-01 03:13:54,600 : INFO : Skipping line #244 with OOV words: impartiality	interest	5.16
# 2024-05-01 03:13:54,600 : INFO : Skipping line #259 with OOV words: calculation	computation	8.44
# 2024-05-01 03:13:54,601 : INFO : Skipping line #276 with OOV words: five	month	3.38
# 2024-05-01 03:13:54,603 : INFO : Pearson correlation coefficient against wordsim353.tsv: 0.6132
# 2024-05-01 03:13:54,604 : INFO : Spearman rank-order correlation coefficient against wordsim353.tsv: 0.6423
# 2024-05-01 03:13:54,604 : INFO : Pairs with unknown words ratio: 2.8%
# 2024-05-01 03:13:54,604 : INFO :  Similarity evaluation: (PearsonRResult(statistic=0.6131596332292173, pvalue=8.486938230998254e-37), SignificanceResult(statistic=0.6422677057898332, pvalue=2.758045939686202e-41), 2.8328611898017)
# 2024-05-01 03:13:54,608 : INFO : Evaluating word analogies for top 30000 words in the model on questions-words.txt
# Computing time for training the model: 70.08129405975342 seconds
# Number of words processed per second: 731724.3879126571
# Most frequent words in model: ['said', 'he', 'his', 'she', 'people', 'new', 'says', 'her', 'year', 'time']
# Model saved to /Users/eddyji/GitRepos/01_TAD/models/cbs/2010-2014.model
# 2024-05-01 03:13:55,182 : INFO : capital-common-countries: 67.5% (312/462)
# 2024-05-01 03:13:56,702 : INFO : capital-world: 58.1% (697/1200)
# 2024-05-01 03:13:56,739 : INFO : currency: 12.5% (5/40)
# 2024-05-01 03:13:58,958 : INFO : city-in-state: 70.9% (1606/2266)
# 2024-05-01 03:13:59,340 : INFO : family: 53.6% (225/420)
# 2024-05-01 03:14:00,194 : INFO : gram1-adjective-to-adverb: 16.5% (134/812)
# 2024-05-01 03:14:00,607 : INFO : gram2-opposite: 17.6% (67/380)
# 2024-05-01 03:14:01,759 : INFO : gram3-comparative: 43.5% (579/1332)
# 2024-05-01 03:14:02,614 : INFO : gram4-superlative: 21.3% (211/992)
# 2024-05-01 03:14:03,181 : INFO : gram5-present-participle: 45.4% (319/702)
# 2024-05-01 03:14:04,184 : INFO : gram6-nationality-adjective: 82.3% (1012/1229)
# 2024-05-01 03:14:05,458 : INFO : gram7-past-tense: 44.1% (688/1560)
# 2024-05-01 03:14:06,440 : INFO : gram8-plural: 68.2% (765/1122)
# 2024-05-01 03:14:06,794 : INFO : gram9-plural-verbs: 24.5% (103/420)
# 2024-05-01 03:14:06,796 : INFO : Quadruplets with out-of-vocabulary words: 33.8%
# 2024-05-01 03:14:06,797 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2024-05-01 03:14:06,798 : INFO : Total accuracy: 52.0% (6723/12937)
# 2024-05-01 03:14:06,800 : INFO : ----------------------------------------------------
# Processing interval 2015-2019
# 2024-05-01 03:14:08,837 : INFO : loading Word2Vec object from /Users/eddyji/GitRepos/01_TAD/models/cbs/2010-2014.model
# 2024-05-01 03:14:08,853 : INFO : loading wv recursively from /Users/eddyji/GitRepos/01_TAD/models/cbs/2010-2014.model.wv.* with mmap=None
# 2024-05-01 03:14:08,853 : INFO : loading vectors from /Users/eddyji/GitRepos/01_TAD/models/cbs/2010-2014.model.wv.vectors.npy with mmap=None
# 2024-05-01 03:14:08,886 : INFO : loading syn1neg from /Users/eddyji/GitRepos/01_TAD/models/cbs/2010-2014.model.syn1neg.npy with mmap=None
# 2024-05-01 03:14:08,936 : INFO : setting ignored attribute cum_table to None
# Loading model from /Users/eddyji/GitRepos/01_TAD/models/cbs/2010-2014.model
# 2024-05-01 03:14:09,248 : INFO : Word2Vec lifecycle event {'fname': '/Users/eddyji/GitRepos/01_TAD/models/cbs/2010-2014.model', 'datetime': '2024-05-01T03:14:09.248379', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'loaded'}
# 2024-05-01 03:14:09,248 : INFO : collecting all words and their counts
# 2024-05-01 03:14:09,248 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2024-05-01 03:14:09,428 : INFO : PROGRESS: at sentence #10000, processed 2586396 words, keeping 81607 word types
# 2024-05-01 03:14:09,613 : INFO : PROGRESS: at sentence #20000, processed 5204377 words, keeping 126713 word types
# 2024-05-01 03:14:09,800 : INFO : PROGRESS: at sentence #30000, processed 7875535 words, keeping 160195 word types
# 2024-05-01 03:14:09,994 : INFO : PROGRESS: at sentence #40000, processed 10634564 words, keeping 189692 word types
# 2024-05-01 03:14:10,179 : INFO : PROGRESS: at sentence #50000, processed 13249444 words, keeping 217318 word types
# 2024-05-01 03:14:10,374 : INFO : PROGRESS: at sentence #60000, processed 16075806 words, keeping 242897 word types
# 2024-05-01 03:14:10,565 : INFO : PROGRESS: at sentence #70000, processed 18917008 words, keeping 267244 word types
# 2024-05-01 03:14:10,755 : INFO : PROGRESS: at sentence #80000, processed 21800969 words, keeping 290923 word types
# 2024-05-01 03:14:10,944 : INFO : PROGRESS: at sentence #90000, processed 24707865 words, keeping 312889 word types
# 2024-05-01 03:14:11,137 : INFO : PROGRESS: at sentence #100000, processed 27595908 words, keeping 334766 word types
# 2024-05-01 03:14:11,338 : INFO : PROGRESS: at sentence #110000, processed 30547285 words, keeping 356468 word types
# 2024-05-01 03:14:11,540 : INFO : PROGRESS: at sentence #120000, processed 33630670 words, keeping 377800 word types
# 2024-05-01 03:14:11,749 : INFO : PROGRESS: at sentence #130000, processed 36869377 words, keeping 399218 word types
# 2024-05-01 03:14:11,923 : INFO : collected 415378 word types from a corpus of 39507661 raw words and 137473 sentences
# 2024-05-01 03:14:11,924 : INFO : Updating model with new vocabulary
# 2024-05-01 03:14:12,171 : INFO : Word2Vec lifecycle event {'msg': 'added 29485 new unique words (7.10% of original 415378) and increased the count of 74966 pre-existing words (18.05% of original 415378)', 'datetime': '2024-05-01T03:14:12.171548', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2024-05-01 03:14:12,333 : INFO : deleting the raw counts dictionary of 415378 items
# 2024-05-01 03:14:12,337 : INFO : sample=0.0001 downsamples 652 most-common words
# 2024-05-01 03:14:12,337 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 31007090.793495324 word corpus (79.3%% of prior 39082683)', 'datetime': '2024-05-01T03:14:12.337452', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2024-05-01 03:14:12,732 : INFO : estimated required memory for 104451 words and 300 dimensions: 302907900 bytes
# ...
# 2024-05-01 04:37:15,419 : INFO : EPOCH 4 - PROGRESS: at 40.93% examples, 2559318 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 04:37
words/s, in_qsize 27, out_qsize 0
# 2024-05-01 04:38:21,614 : INFO : EPOCH 4 - PROGRESS: at 88.24% examples, 2544201 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 04:38:22,619 : INFO : EPOCH 4 - PROGRESS: at 88.90% examples, 2544169 words/s, in_qsize 26, out_qsize 1
# 2024-05-01 04:38:23,620 : INFO : EPOCH 4 - PROGRESS: at 89.59% examples, 2544278 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 04:38:24,624 : INFO : EPOCH 4 - PROGRESS: at 90.28% examples, 2544406 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 04:38:25,625 : INFO : EPOCH 4 - PROGRESS: at 90.95% examples, 2543976 words/s, in_qsize 26, out_qsize 1
# 2024-05-01 04:38:26,629 : INFO : EPOCH 4 - PROGRESS: at 91.64% examples, 2544054 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 04:38:27,632 : INFO : EPOCH 4 - PROGRESS: at 92.33% examples, 2544171 words/s, in_qsize 26, out_qsize 1
# 2024-05-01 04:38:28,634 : INFO : EPOCH 4 - PROGRESS: at 93.00% examples, 2544309 words/s, in_qsize 28, out_qsize 0
# 2024-05-01 04:38:29,637 : INFO : EPOCH 4 - PROGRESS: at 93.69% examples, 2544597 words/s, in_qsize 26, out_qsize 1
# 2024-05-01 04:38:30,637 : INFO : EPOCH 4 - PROGRESS: at 94.36% examples, 2544585 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 04:38:31,640 : INFO : EPOCH 4 - PROGRESS: at 94.99% examples, 2544080 words/s, in_qsize 26, out_qsize 1
# 2024-05-01 04:38:32,640 : INFO : EPOCH 4 - PROGRESS: at 95.66% examples, 2544259 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 04:38:33,640 : INFO : EPOCH 4 - PROGRESS: at 96.33% examples, 2544409 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 04:38:34,644 : INFO : EPOCH 4 - PROGRESS: at 97.01% examples, 2544539 words/s, in_qsize 28, out_qsize 0
# 2024-05-01 04:38:35,645 : INFO : EPOCH 4 - PROGRESS: at 97.68% examples, 2544715 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 04:38:36,650 : INFO : EPOCH 4 - PROGRESS: at 98.33% examples, 2544288 words/s, in_qsize 26, out_qsize 1
# 2024-05-01 04:38:37,652 : INFO : EPOCH 4 - PROGRESS: at 99.00% examples, 2544285 words/s, in_qsize 28, out_qsize 0
# 2024-05-01 04:38:38,652 : INFO : EPOCH 4 - PROGRESS: at 99.67% examples, 2544449 words/s, in_qsize 27, out_qsize 0
# 2024-05-01 04:38:39,124 : INFO : EPOCH 4: training on 446366832 raw words (358446332 effective words) took 140.9s, 2544524 effective words/s
# 2024-05-01 04:38:39,124 : INFO : Word2Vec lifecycle event {'msg': 'training on 2231834160 raw words (1792238694 effective words) took 664.5s, 2697139 effective words/s', 'datetime': '2024-05-01T04:38:39.124918', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'train'}
# Computing time for training the model: 708.8723270893097 seconds
# 2024-05-01 04:38:43,610 : INFO : Word2Vec lifecycle event {'fname_or_handle': '/Users/eddyji/GitRepos/01_TAD/models/dailymail/2015-2019.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2024-05-01T04:38:43.610633', 'gensim': '4.3.2', 'python': '3.11.5 (main, Sep 11 2023, 08:17:37) [Clang 14.0.6 ]', 'platform': 'macOS-14.4.1-arm64-arm-64bit', 'event': 'saving'}
# 2024-05-01 04:38:43,611 : INFO : storing np array 'vectors' to /Users/eddyji/GitRepos/01_TAD/models/dailymail/2015-2019.model.wv.vectors.npy
# 2024-05-01 04:38:43,676 : INFO : storing np array 'syn1neg' to /Users/eddyji/GitRepos/01_TAD/models/dailymail/2015-2019.model.syn1neg.npy
# 2024-05-01 04:38:43,765 : INFO : not storing attribute cum_table
# Number of words processed per second: 629685.790998247
# Most frequent words in model: ['year', 'said', 'he', 'view', 'comments', 'updated', 'aedt', 'company', 'money', 'new']
# 2024-05-01 04:38:43,903 : INFO : saved /Users/eddyji/GitRepos/01_TAD/models/dailymail/2015-2019.model
# 2024-05-01 04:38:43,913 : INFO : Skipping line #35 with OOV words: king	cabbage	0.23
# 2024-05-01 04:38:43,913 : INFO : Skipping line #37 with OOV words: king	rook	5.92
# 2024-05-01 04:38:43,913 : INFO : Skipping line #42 with OOV words: fuck	sex	9.44
# 2024-05-01 04:38:43,914 : INFO : Skipping line #55 with OOV words: movie	theater	7.92
# 2024-05-01 04:38:43,915 : INFO : Skipping line #87 with OOV words: food	rooster	4.42
# 2024-05-01 04:38:43,916 : INFO : Skipping line #97 with OOV words: rooster	voyage	0.62
# 2024-05-01 04:38:43,916 : INFO : Skipping line #110 with OOV words: tiger	feline	8.00
# 2024-05-01 04:38:43,917 : INFO : Skipping line #111 with OOV words: tiger	carnivore	7.08
# 2024-05-01 04:38:43,917 : INFO : Skipping line #112 with OOV words: tiger	mammal	6.85
# 2024-05-01 04:38:43,917 : INFO : Skipping line #114 with OOV words: tiger	organism	4.77
# 2024-05-01 04:38:43,917 : INFO : Skipping line #115 with OOV words: tiger	fauna	5.62
# 2024-05-01 04:38:43,917 : INFO : Skipping line #117 with OOV words: psychology	psychiatry	8.08
# 2024-05-01 04:38:43,918 : INFO : Skipping line #128 with OOV words: psychology	cognition	7.48
# 2024-05-01 04:38:43,918 : INFO : Skipping line #135 with OOV words: planet	astronomer	7.94
# 2024-05-01 04:38:43,918 : INFO : Skipping line #138 with OOV words: precedent	cognition	2.81
# 2024-05-01 04:38:43,918 : INFO : Skipping line #142 with OOV words: precedent	antecedent	6.04
# 2024-05-01 04:38:43,919 : INFO : Skipping line #146 with OOV words: cup	artifact	2.92
# 2024-05-01 04:38:43,919 : INFO : Skipping line #169 with OOV words: water	seepage	6.56
# 2024-05-01 04:38:43,919 : INFO : Skipping line #172 with OOV words: mile	kilometer	8.66
# 2024-05-01 04:38:43,920 : INFO : Skipping line #181 with OOV words: theater	history	3.91
# 2024-05-01 04:38:43,920 : INFO : Skipping line #184 with OOV words: decoration	valor	5.63
# 2024-05-01 04:38:43,921 : INFO : Skipping line #210 with OOV words: hundred	percent	7.38
# 2024-05-01 04:38:43,921 : INFO : Skipping line #224 with OOV words: territory	kilometer	5.28
# 2024-05-01 04:38:43,922 : INFO : Skipping line #244 with OOV words: impartiality	interest	5.16
# 2024-05-01 04:38:43,922 : INFO : Skipping line #259 with OOV words: calculation	computation	8.44
# 2024-05-01 04:38:43,922 : INFO : Skipping line #276 with OOV words: five	month	3.38
# 2024-05-01 04:38:43,924 : INFO : Skipping line #339 with OOV words: aluminum	metal	7.83
# 2024-05-01 04:38:43,924 : INFO : Skipping line #342 with OOV words: concert	virtuoso	6.81
# 2024-05-01 04:38:43,924 : INFO : Skipping line #344 with OOV words: museum	theater	7.19
# 2024-05-01 04:38:43,928 : INFO : Pearson correlation coefficient against wordsim353.tsv: 0.6443
# 2024-05-01 04:38:43,929 : INFO : Spearman rank-order correlation coefficient against wordsim353.tsv: 0.6716
# 2024-05-01 04:38:43,930 : INFO : Pairs with unknown words ratio: 8.2%
# 2024-05-01 04:38:43,931 : INFO :  Similarity evaluation: (PearsonRResult(statistic=0.6443451154583784, pvalue=2.124173775452608e-39), SignificanceResult(statistic=0.6715950366555037, pvalue=7.673922218628712e-44), 8.21529745042493)
# 2024-05-01 04:38:43,938 : INFO : Evaluating word analogies for top 30000 words in the model on questions-words.txt
# Model saved to /Users/eddyji/GitRepos/01_TAD/models/dailymail/2015-2019.model
# 2024-05-01 04:38:44,404 : INFO : capital-common-countries: 77.9% (296/380)
# 2024-05-01 04:38:44,761 : INFO : capital-world: 77.6% (294/379)
# 2024-05-01 04:38:44,945 : INFO : currency: 15.8% (24/152)
# 2024-05-01 04:38:45,326 : INFO : city-in-state: 69.8% (296/424)
# 2024-05-01 04:38:45,556 : INFO : family: 59.2% (181/306)
# 2024-05-01 04:38:46,298 : INFO : gram1-adjective-to-adverb: 27.5% (223/812)
# 2024-05-01 04:38:46,891 : INFO : gram2-opposite: 12.8% (90/702)
# 2024-05-01 04:38:48,118 : INFO : gram3-comparative: 48.3% (608/1260)
# 2024-05-01 04:38:48,652 : INFO : gram4-superlative: 31.8% (223/702)
# 2024-05-01 04:38:49,195 : INFO : gram5-present-participle: 61.5% (432/702)
# 2024-05-01 04:38:49,775 : INFO : gram6-nationality-adjective: 94.8% (804/848)
# 2024-05-01 04:38:50,912 : INFO : gram7-past-tense: 62.0% (919/1482)
# 2024-05-01 04:38:51,601 : INFO : gram8-plural: 72.8% (591/812)
# 2024-05-01 04:38:51,991 : INFO : gram9-plural-verbs: 31.6% (160/506)
# 2024-05-01 04:38:51,992 : INFO : Quadruplets with out-of-vocabulary words: 51.6%
# 2024-05-01 04:38:51,993 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2024-05-01 04:38:51,994 : INFO : Total accuracy: 54.3% (5141/9467)
# 2024-05-01 04:38:51,997 : INFO : ----------------------------------------------------
# 2024-05-01 04:38:51,999 : INFO : XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX

# %%
import csv
from pathlib import Path

file_name_list = [f'{i[0]}-{i[-1]}' for i in intervalsList]
outlets = ['cbs','nyt', 'slate', 'reuters','thehill', 'csm', 'wt', 'nyp', 'dailymail']

def count_csv_lines(outlets, file_name_list):
    base_dir = Path("../scrambledArticlesForWord2vec")
    line_counts = {}

    csv.field_size_limit(1000000)  # 增加字段大小限制

    for outlet in outlets:
        line_counts[outlet] = {}
        outlet_dir = base_dir / outlet

        for interval in file_name_list:
            interval_dir = outlet_dir / f'{interval}.csv'
            line_count = 0

            with open(interval_dir, "r") as file:
                csv_reader = csv.reader(file)
                line_count = sum(1 for row in csv_reader)

            line_counts[outlet][interval] = line_count

    return line_counts

count = count_csv_lines(outlets, file_name_list)
count_df = pd.DataFrame(count)
count_df
# Out:
#               cbs     nyt  slate  reuters  thehill    csm       wt     nyp  \
# 2000-2004   60869  421143  15313        6        6  42787   104164  146136
# 2005-2009  155509  303699  26045   790883    37352  44535   150534  187012
# 2010-2014  203569  460506  61621  1322954   155641  92239   513780  257433
# 2015-2019  137473  290703  61284  1180341   220846  48144  1299226  255737
#
#            dailymail
# 2000-2004      64491
# 2005-2009     170786
# 2010-2014     803932
# 2015-2019    1356851
